# %% [markdown]
# <a href="https://colab.research.google.com/github/Pritesh631/flyrank-ml-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Pritesh631/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# Lane: Fake Job Post Detection
# I want to explore how machine learning can be used to identify potentially fraudulent job postings. My question is: Which features of a job posting are most useful for distinguishing legitimate job advertisements from potentially fraudulent ones? I chose this topic because fake job postings can waste applicants’ time, expose them to scams, and reduce trust in online recruitment platforms. A useful model could help prioritize suspicious postings for further review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Decision: Identify whether a job posting should be considered potentially fraudulent and flagged for further review.
# Action: A recruiter or platform moderator can review flagged postings and take appropriate action.
# Cost of a wrong call: A false positive may cause a legitimate job posting to be unnecessarily reviewed or delayed, while a false negative may expose job seekers to scams, wasted time, or potential financial loss.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run Allimport pandas as p
import os
import pandas as pd

# Clone your GitHub repository into Colab
# !git clone https://github.com/Pritesh631/flyrank-ml-internship.git

# Load the actual project dataset
file_path = "/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(file_path)

print("Dataset shape:", df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nThree sample rows:")
display(df.head(3))
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 123 (delta 37), reused 97 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 1.85 MiB | 4.78 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# Dataset shape: (30000, 44)
#
# Columns:
# ...

# %% [markdown]
# What I can claim: My analysis can identify observed patterns and measured relationships between job-posting features and indicators of potentially fraudulent postings. The findings can provide directional insights and decision support for prioritizing suspicious postings for further review.
#
# What I cannot claim: The analysis cannot establish causal relationships, prove that a particular feature causes fraud, or guarantee that a posting is fraudulent. It also cannot predict outcomes outside the available data or claim to “predict Google.”

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ✓ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ✓ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [  ✓] No client names, URLs, or private queries anywhere
# - [ ✓ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ✓ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
